# %%
import numpy as np

print("Lets play a game!")
print("First, lets give your players their stats.")
# Out:
# Lets play a game!
# First, lets give your players their stats.

# %%
name1=input("What's your first players name?")
hp1=np.random.randint(40,100)
Types=('red','blue','pink','orange','green')
tp1=np.random.choice(Types)
atk1n1=np.random.randint(5,20)
atk2n1=np.random.randint(15,40)
print(f"{name1}'s stats are:")
print(f"hp: {hp1}, type: {tp1}, first attack: {atk1n1}, second attack: {atk2n1}")
player1=[name1,hp1,tp1,atk1n1,atk2n1]
# Out:
# What's your first players name?Gary
# Gary's stats are:
# hp: 74, type: orange, first attack: 14, second attack: 25

# %%
name2=input("What's your second players name?")
hp2=np.random.randint(40,100)
tp2=np.random.choice(Types)
atk1n2=np.random.randint(5,20)
atk2n2=np.random.randint(15,40)
print(f"{name2}'s stats are:")
print(f"hp: {hp2}, type: {tp2}, first attack: {atk1n2}, second attack: {atk2n2}")
player2=[name2,hp2,tp2,atk1n2,atk2n2]
# Out:
# What's your second players name?Reggie
# Reggie's stats are:
# hp: 60, type: red, first attack: 16, second attack: 16

# %%
name3=input("What's your third players name?")
hp3=np.random.randint(40,100)
tp3=np.random.choice(Types)
atk1n3=np.random.randint(5,20)
atk2n3=np.random.randint(15,40)
print(f"{name3}'s stats are:")
print(f"hp: {hp3}, type: {tp3}, first attack: {atk1n3}, second attack: {atk2n3}")
player3=[name3,hp3,tp3,atk1n3,atk2n3]
# Out:
# What's your third players name?Leo
# Leo's stats are:
# hp: 63, type: orange, first attack: 15, second attack: 32

# %%
print("Generating players for the computer...")
names=['Jerry','Ted','Karl','Tom','Gerald']
name4=np.random.choice(names)
names.remove(name4)
name5=np.random.choice(names)
names.remove(name5)
name6=np.random.choice(names)

hp4=np.random.randint(40,100)
tp4=np.random.choice(Types)
atk1n4=np.random.randint(5,20)
atk2n4=np.random.randint(15,40)
player4=[name4,hp4,tp4,atk1n4,atk2n4]

hp5=np.random.randint(40,100)
tp5=np.random.choice(Types)
atk1n5=np.random.randint(5,20)
atk2n5=np.random.randint(15,40)
player5=[name5,hp5,tp5,atk1n5,atk2n5]

hp6=np.random.randint(40,100)
tp6=np.random.choice(Types)
atk1n6=np.random.randint(5,20)
atk2n6=np.random.randint(15,40)
player6=[name6,hp6,tp6,atk1n6,atk2n6]
print(f"Your opponent now has the players {name4}, {name5}, and {name6}.")
# Out:
# Generating players for the computer...
# Your opponent now has the players Gerald, Karl, and Ted.

# %%
print("Here's your players: ")
print(name1)
print(f"hp: {hp1}, type: {tp1}, first attack: {atk1n1}, second attack: {atk2n1}")
print(name2)
print(f"hp: {hp2}, type: {tp2}, first attack: {atk1n2}, second attack: {atk2n2}")
print(name3)
print(f"hp: {hp3}, type: {tp3}, first attack: {atk1n3}, second attack: {atk2n3}")
coin=('heads','tails')
flip=np.random.choice(coin)
aiplay=[4,5,6]
round1=np.random.choice(aiplay)
aiplay.remove(round1)
if round1==4:
    round1=player4
elif round1==5:
    round1=player5
else:
    round1=player6

if flip=='heads':
    print("You are going first")
else:
    print("You are going second")
    print(f"The computer is starting with {round1[0]}.")
    print(f"{round1[0]}'s stats are: ")
    print(f"hp: {round1[1]}, type: {round1[2]}, first attack: {round1[3]}, second attack: {round1[4]}")

i=0
while i==0:
    rlrd1=input("Which player would you like to start with?")
    if rlrd1==name1:
        print(f"You are starting with {name1}!")
        rlrd1=player1
        i=1
    elif rlrd1==name2:
        print(f"You are starting with {name2}!")
        rlrd1=player2
        i=1
    elif rlrd1==name3:
        print(f"You are starting with {name3}!")
        rlrd1=player3
        i=1
    else:
        print("That is not one of your players, try again.")
# Out:
# Here's your players:
# Gary
# hp: 74, type: orange, first attack: 14, second attack: 25
# Reggie
# hp: 60, type: red, first attack: 16, second attack: 16
# Leo
# hp: 63, type: orange, first attack: 15, second attack: 32
# You are going second
# The computer is starting with Karl.
# Karl's stats are:
# hp: 53, type: pink, first attack: 19, second attack: 30
# Which player would you like to start with?Leo
# You are starting with Leo!

# %%
# layer 1
if flip=='heads':
    print(f"The computer is starting with {round1[0]}.")
    print(f"{round1[0]}'s stats are: ")
    print(f"hp: {round1[1]}, type: {round1[2]}, first attack: {round1[3]}, second attack: {round1[4]}")
    while round1[1]>0 and rlrd1[1]>0:
        print(f"Attack 1: {rlrd1[3]}     Attack 2: {rlrd1[4]}")
        choice=int(input(f"Which attack would you like to use on {round1[0]}?"))
        if choice==1:
            print(f"{round1[0]} took {rlrd1[3]} damage!")
            round1[1]=round1[1]-rlrd1[3]
            print(f"They now have {round1[1]} health.")
        elif choice==2:
            print(f"{round1[0]} took {rlrd1[4]} damage!")
            round1[1]=round1[1]-rlrd1[4]
            print(f"{round1[0]} now has {round1[1]} health.")
        else:
            print('Nonvalid option')
        if round1[1]<=0:
            break
        else:
            print()
        print("Now it is the computers turn.")
        option=(1,2)
        choose=np.random.choice(option)
        if choose==1:
            print(f"Now {rlrd1[0]} has taken {round1[3]} damage.")
            rlrd1[1]=rlrd1[1]-round1[3]
            print(f"They now have {rlrd1[1]} health.")
        else:
            print(f"Now {rlrd1[0]} has taken {round1[4]} damage.")
            rlrd1[1]=rlrd1[1]-round1[4]
            print(f"They now have {rlrd1[1]} health.")
    if round1[1]<=0:
        print(f"You have defeated {round1[0]}!")
        round2=np.random.choice(aiplay)
        aiplay.remove(round2)
        if round2==4:
            round2=player4
            print(f"The computer has now chosen {round2[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        elif round2==5:
            round2=player5
            print(f"The computer has now chosen {round2[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        else:
            round2=player6
            print(f"The computer has now chosen {round2[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        if ans==1:
            print("Great! Lets go.")
        else:
            print("Game Over")
    else:
        print(f"Oh no! {rlrd1[0]} has been defeated!")
        print(f"You have two players left, would you like to continue or conceed?")
        ans=int(input("Continue=1     Conceed=2"))
        if ans==1:
            print("Great! Lets go.")
        else:
            print("You have conceeded to the computer. The computer wins.")
else:
    print(f"The computer is starting with {round1[0]}.")
    while round1[1]>0 and rlrd1[1]>0:
        option=(1,2)
        choose=np.random.choice(option)
        if choose==1:
            print(f"{rlrd1[0]} has taken {round1[3]} damage!")
            rlrd1[1]=rlrd1[1]-round1[3]
            print(f"They now have {rlrd1[1]} health.")
        else:
            print(f"{rlrd1[0]} has taken {round1[4]} damage!")
            rlrd1[1]=rlrd1[1]-round1[4]
            print(f"They now have {rlrd1[1]} health.")
        if rlrd1[1]<=0:
            break
        else:
            print()
        print(f"Attack 1: {rlrd1[3]}     Attack 2: {rlrd1[4]}")
        choice=int(input(f"Which attack would you like to use on {round1[0]}?"))
        if choice==1:
            print(f"{round1[0]} took {rlrd1[3]} damage!")
            round1[1]=round1[1]-rlrd1[3]
            print(f"They now have {round1[1]} health.")
        elif choice==2:
            print(f"{round1[0]} took {rlrd1[4]} damage!")
            round1[1]=round1[1]-rlrd1[4]
            print(f"{round1[0]} now has {round1[1]} health.")
        else:
            print('Nonvalid option')
    if round1[1]<=0:
        print(f"You have defeated {round1[0]}!")
        round2=np.random.choice(aiplay)
        aiplay.remove(round2)
        if round2==4:
            round2=player4
            print(f"The computer has now chosen {round2[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        elif round2==5:
            round2=player5
            print(f"The computer has now chosen {round2[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        else:
            round2=player6
            print(f"The computer has now chosen {round2[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        if ans==1:
            print("Great! Lets go.")
        else:
            print("Game Over")
    else:
        print(f"Oh no! {rlrd1[0]} has been defeated!")
        print(f"You have two players left, would you like to continue or conceed?")
        ans=int(input("Continue=1     Conceed=2"))
        if ans==1:
            print("Great! Lets go.")
        else:
            print("You have conceeded to the computer. The computer wins.")
        print("Here's your players: ")
        print(name1)
        print(f"hp: {hp1}, type: {tp1}, first attack: {atk1n1}, second attack: {atk2n1}")
        print(name2)
        print(f"hp: {hp2}, type: {tp2}, first attack: {atk1n2}, second attack: {atk2n2}")
        print(name3)
        print(f"hp: {hp3}, type: {tp3}, first attack: {atk1n3}, second attack: {atk2n3}")
        i=0
        while i==0:
            rlrd2=input("Which player would you like to switch to?")
            if rlrd2==name1:
                print(f"You are continuing with {name1}!")
                rlrd2=player1
                i=1
            elif rlrd2==name2:
                print(f"You are continuing with {name2}!")
                rlrd2=player2
                i=1
            elif rlrd2==name3:
                print(f"You are continuing with {name3}!")
                rlrd2=player3
                i=1
            else:
                print("That is not one of your players, try again.")
# Out:
# The computer is starting with Karl.
# Leo has taken 30 damage!
# They now have 33 health.
#
# Attack 1: 15     Attack 2: 32
# Which attack would you like to use on Karl?2
# Karl took 32 damage!
# Karl now has 21 health.
# Leo has taken 19 damage!
# They now have 14 health.
#
# Attack 1: 15     Attack 2: 32
# Which attack would you like to use on Karl?2
# Karl took 32 damage!
# Karl now has -11 health.
# You have defeated Karl!
# The computer has now chosen Gerald to compete.
# Would you like to continue or conceed?
# Continue=1     Conceed=21
# Great! Lets go.

# %%
# layer 2
if round1[1]>=0:
    print(f"The computer is starting with {round1[0]}.")
    print(f"{round1[0]}'s stats are: ")
    print(f"hp: {round1[1]}, type: {round1[2]}, first attack: {round1[3]}, second attack: {round1[4]}")
    while round1[1]>0 and rlrd2[1]>0:
        print(f"Attack 1: {rlrd2[3]}     Attack 2: {rlrd2[4]}")
        choice=int(input(f"Which attack would you like to use on {round1[0]}?"))
        if choice==1:
            print(f"{round1[0]} took {rlrd2[3]} damage!")
            round1[1]=round1[1]-rlrd2[3]
            print(f"They now have {round1[1]} health.")
        elif choice==2:
            print(f"{round1[0]} took {rlrd2[4]} damage!")
            round1[1]=round1[1]-rlrd2[4]
            print(f"{round1[0]} now has {round1[1]} health.")
        else:
            print('Nonvalid option')
        if round1[1]<=0:
            break
        else:
            print()
        print("Now it is the computers turn.")
        option=(1,2)
        choose=np.random.choice(option)
        if choose==1:
            print(f"Now {rlrd2[0]} has taken {round1[3]} damage.")
            rlrd2[1]=rlrd2[1]-round1[3]
            print(f"They now have {rlrd2[1]} health.")
        else:
            print(f"Now {rlrd2[0]} has taken {round1[4]} damage.")
            rlrd2[1]=rlrd2[1]-round1[4]
            print(f"They now have {rlrd2[1]} health.")
    if round1[1]<=0:
        print(f"You have defeated {round1[0]}!")
        round2=np.random.choice(aiplay)
        aiplay.remove(round2)
        if round2==4:
            round2=player4
            print(f"The computer has now chosen {round2[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        elif round2==5:
            round2=player5
            print(f"The computer has now chosen {round2[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        else:
            round2=player6
            print(f"The computer has now chosen {round2[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        if ans==1:
            print("Great! Lets go.")
        else:
            print("Game Over")
    else:
        print(f"Oh no! {rlrd2[0]} has been defeated!")
        print(f"You have two players left, would you like to continue or conceed?")
        ans=int(input("Continue=1     Conceed=2"))
        if ans==1:
            print("Great! Lets go.")
        else:
            print("You have conceeded to the computer. The computer wins.")
else:
    print(f"The computer is starting with {round2[0]}.")
    while round2[1]>0 and rlrd1[1]>0:
        option=(1,2)
        choose=np.random.choice(option)
        if choose==1:
            print(f"{rlrd1[0]} has taken {round2[3]} damage!")
            rlrd1[1]=rlrd1[1]-round2[3]
            print(f"They now have {rlrd1[1]} health.")
        else:
            print(f"{rlrd1[0]} has taken {round2[4]} damage!")
            rlrd1[1]=rlrd1[1]-round2[4]
            print(f"They now have {rlrd1[1]} health.")
        if rlrd1[1]<=0:
            break
        else:
            print()
        print(f"Attack 1: {rlrd1[3]}     Attack 2: {rlrd1[4]}")
        choice=int(input(f"Which attack would you like to use on {round2[0]}?"))
        if choice==1:
            print(f"{round2[0]} took {rlrd1[3]} damage!")
            round2[1]=round2[1]-rlrd1[3]
            print(f"They now have {round2[1]} health.")
        elif choice==2:
            print(f"{round2[0]} took {rlrd1[4]} damage!")
            round2[1]=round2[1]-rlrd1[4]
            print(f"{round2[0]} now has {round2[1]} health.")
        else:
            print('Nonvalid option')
    if round2[1]<=0:
        print(f"You have defeated {round2[0]}!")
        round3=np.random.choice(aiplay)
        aiplay.remove(round3)
        if round3==4:
            round3=player4
            print(f"The computer has now chosen {round2[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        elif round3==5:
            round3=player5
            print(f"The computer has now chosen {round2[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        else:
            round3=player6
            print(f"The computer has now chosen {round2[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        if ans==1:
            print("Great! Lets go.")
        else:
            print("Game Over")
    else:
        print(f"Oh no! {rlrd1[0]} has been defeated!")
        print(f"You have two players left, would you like to continue or conceed?")
        ans=int(input("Continue=1     Conceed=2"))
        if ans==1:
            print("Great! Lets go.")
        else:
            print("You have conceeded to the computer. The computer wins.")
        print("Here's your players: ")
        print(name1)
        print(f"hp: {hp1}, type: {tp1}, first attack: {atk1n1}, second attack: {atk2n1}")
        print(name2)
        print(f"hp: {hp2}, type: {tp2}, first attack: {atk1n2}, second attack: {atk2n2}")
        print(name3)
        print(f"hp: {hp3}, type: {tp3}, first attack: {atk1n3}, second attack: {atk2n3}")
        i=0
        while i==0:
            rlrd3=input("Which player would you like to switch to?")
            if rlrd3==name1:
                print(f"You are continuing with {name1}!")
                rlrd3=player1
                i=1
            elif rlrd3==name2:
                print(f"You are continuing with {name2}!")
                rlrd3=player2
                i=1
            elif rlrd3==name3:
                print(f"You are continuing with {name3}!")
                rlrd3=player3
                i=1
            else:
                print("That is not one of your players, try again.")
# Out:
# The computer is starting with Gerald.
# Leo has taken 11 damage!
# They now have 3 health.
#
# Attack 1: 15     Attack 2: 32
# Which attack would you like to use on Gerald?2
# Gerald took 32 damage!
# Gerald now has 42 health.
# Leo has taken 23 damage!
# They now have -20 health.
# Oh no! Leo has been defeated!
# You have two players left, would you like to continue or conceed?
# Continue=1     Conceed=21
# Great! Lets go.
# Here's your players:
# Gary
# hp: 74, type: orange, first attack: 14, second attack: 25
# Reggie
# hp: 60, type: red, first attack: 16, second attack: 16
# Leo
# hp: 63, type: orange, first attack: 15, second attack: 32
# Which player would you like to switch to?Gary
# You are continuing with Gary!

# %%
# level 3
if round1[1]>0:
    print(f"The computer is starting with {round1[0]}.")
    print(f"{round1[0]}'s stats are: ")
    print(f"hp: {round1[1]}, type: {round1[2]}, first attack: {round1[3]}, second attack: {round1[4]}")
    while round1[1]>0 and rlrd3[1]>0:
        print(f"Attack 1: {rlrd3[3]}     Attack 2: {rlrd3[4]}")
        choice=int(input(f"Which attack would you like to use on {round1[0]}?"))
        if choice==1:
            print(f"{round1[0]} took {rlrd3[3]} damage!")
            round1[1]=round1[1]-rlrd3[3]
            print(f"They now have {round1[1]} health.")
        elif choice==2:
            print(f"{round1[0]} took {rlrd3[4]} damage!")
            round1[1]=round1[1]-rlrd3[4]
            print(f"{round1[0]} now has {round1[1]} health.")
        else:
            print('Nonvalid option')
        if round1[1]<=0:
            break
        else:
            print()
        print("Now it is the computers turn.")
        option=(1,2)
        choose=np.random.choice(option)
        if choose==1:
            print(f"Now {rlrd3[0]} has taken {round1[3]} damage.")
            rlrd3[1]=rlrd3[1]-round1[3]
            print(f"They now have {rlrd3[1]} health.")
        else:
            print(f"Now {rlrd3[0]} has taken {round1[4]} damage.")
            rlrd3[1]=rlrd3[1]-round1[4]
            print(f"They now have {rlrd3[1]} health.")
    if round1[1]<=0:
        print(f"You have defeated {round1[0]}!")
        round2=np.random.choice(aiplay)
        aiplay.remove(round2)
        if round2==4:
            round2=player4
            print(f"The computer has now chosen {round2[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        elif round2==5:
            round2=player5
            print(f"The computer has now chosen {round2[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        else:
            round2=player6
            print(f"The computer has now chosen {round2[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        if ans==1:
            print("Great! Lets go.")
        else:
            print("Game Over")
    else:
        print(f"Oh no! {rlrd3[0]} has been defeated!")
        print("You have lost the game. Better luck next time.")
elif rlrd1[1]>0:
    print(f"The computer is starting with {round3[0]}.")
    while round3[1]>0 and rlrd1[1]>0:
        option=(1,2)
        choose=np.random.choice(option)
        if choose==1:
            print(f"{rlrd1[0]} has taken {round3[3]} damage!")
            rlrd1[1]=rlrd1[1]-round3[3]
            print(f"They now have {rlrd1[1]} health.")
        else:
            print(f"{rlrd1[0]} has taken {round3[4]} damage!")
            rlrd1[1]=rlrd1[1]-round3[4]
            print(f"They now have {rlrd1[1]} health.")
        if rlrd1[1]<=0:
            break
        else:
            print()
        print(f"Attack 1: {rlrd1[3]}     Attack 2: {rlrd1[4]}")
        choice=int(input(f"Which attack would you like to use on {round3[0]}?"))
        if choice==1:
            print(f"{round3[0]} took {rlrd1[3]} damage!")
            round3[1]=round3[1]-rlrd1[3]
            print(f"They now have {round1[1]} health.")
        elif choice==2:
            print(f"{round3[0]} took {rlrd1[4]} damage!")
            round3[1]=round3[1]-rlrd1[4]
            print(f"{round3[0]} now has {round3[1]} health.")
        else:
            print('Nonvalid option')
    if round3[1]<=0:
        print(f"You have defeated {round3[0]}!")
        print("Congratulations, you have won the game!")
    else:
        print(f"Oh no! {rlrd1[0]} has been defeated!")
        print(f"You have two players left, would you like to continue or conceed?")
        ans=int(input("Continue=1     Conceed=2"))
        if ans==1:
            print("Great! Lets go.")
        else:
            print("You have conceeded to the computer. The computer wins.")
        print("Here's your players: ")
        print(name1)
        print(f"hp: {hp1}, type: {tp1}, first attack: {atk1n1}, second attack: {atk2n1}")
        print(name2)
        print(f"hp: {hp2}, type: {tp2}, first attack: {atk1n2}, second attack: {atk2n2}")
        print(name3)
        print(f"hp: {hp3}, type: {tp3}, first attack: {atk1n3}, second attack: {atk2n3}")
        i=0
        while i==0:
            rlrd2=input("Which player would you like to switch to?")
            if rlrd2==name1:
                print(f"You are continuing with {name1}!")
                rlrd2=player1
                i=1
            elif rlrd2==name2:
                print(f"You are continuing with {name2}!")
                rlrd2=player2
                i=1
            elif rlrd2==name3:
                print(f"You are continuing with {name3}!")
                rlrd2=player3
                i=1
            else:
                print("That is not one of your players, try again.")
else:
    print(f"The computer is starting with {round2[0]}.")
    while round2[1]>0 and rlrd2[1]>0:
        option=(1,2)
        choose=np.random.choice(option)
        if choose==1:
            print(f"{rlrd2[0]} has taken {round2[3]} damage!")
            rlrd2[1]=rlrd2[1]-round2[3]
            print(f"They now have {rlrd2[1]} health.")
        else:
            print(f"{rlrd2[0]} has taken {round2[4]} damage!")
            rlrd2[1]=rlrd2[1]-round2[4]
            print(f"They now have {rlrd2[1]} health.")
        if rlrd2[1]<=0:
            break
        else:
            print()
        print(f"Attack 1: {rlrd2[3]}     Attack 2: {rlrd2[4]}")
        choice=int(input(f"Which attack would you like to use on {round2[0]}?"))
        if choice==1:
            print(f"{round2[0]} took {rlrd2[3]} damage!")
            round2[1]=round2[1]-rlrd2[3]
            print(f"They now have {round2[1]} health.")
        elif choice==2:
            print(f"{round2[0]} took {rlrd2[4]} damage!")
            round2[1]=round2[1]-rlrd2[4]
            print(f"{round2[0]} now has {round2[1]} health.")
        else:
            print('Nonvalid option')
    if round2[1]<=0:
        print(f"You have defeated {round2[0]}!")
        round3=np.random.choice(aiplay)
        aiplay.remove(round3)
        if round3==4:
            round3=player4
            print(f"The computer has now chosen {round2[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        elif round3==5:
            round3=player5
            print(f"The computer has now chosen {round2[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        else:
            round3=player6
            print(f"The computer has now chosen {round2[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        if ans==1:
            print("Great! Lets go.")
        else:
            print("Game Over")
    else:
        print(f"Oh no! {rlrd2[0]} has been defeated!")
        print(f"You have two players left, would you like to continue or conceed?")
        ans=int(input("Continue=1     Conceed=2"))
        if ans==1:
            print("Great! Lets go.")
        else:
            print("You have conceeded to the computer. The computer wins.")
        print("Here's your players: ")
        print(name1)
        print(f"hp: {hp1}, type: {tp1}, first attack: {atk1n1}, second attack: {atk2n1}")
        print(name2)
        print(f"hp: {hp2}, type: {tp2}, first attack: {atk1n2}, second attack: {atk2n2}")
        print(name3)
        print(f"hp: {hp3}, type: {tp3}, first attack: {atk1n3}, second attack: {atk2n3}")
        i=0
        while i==0:
            rlrd3=input("Which player would you like to switch to?")
            if rlrd3==name1:
                print(f"You are continuing with {name1}!")
                rlrd3=player1
                i=1
            elif rlrd3==name2:
                print(f"You are continuing with {name2}!")
                rlrd3=player2
                i=1
            elif rlrd3==name3:
                print(f"You are continuing with {name3}!")
                rlrd3=player3
                i=1
            else:
                print("That is not one of your players, try again.")
# Out:
# The computer is starting with Gerald.
# Oh no! Reginald has been defeated!
# You have two players left, would you like to continue or conceed?

# %%
# level 4
if round2[1]>0:
    print(f"The computer is starting with {round2[0]}.")
    print(f"{round2[0]}'s stats are: ")
    print(f"hp: {round2[1]}, type: {round2[2]}, first attack: {round2[3]}, second attack: {round2[4]}")
    while round2[1]>0 and rlrd3[1]>0:
        print(f"Attack 1: {rlrd3[3]}     Attack 2: {rlrd3[4]}")
        choice=int(input(f"Which attack would you like to use on {round2[0]}?"))
        if choice==1:
            print(f"{round2[0]} took {rlrd3[3]} damage!")
            round2[1]=round2[1]-rlrd3[3]
            print(f"They now have {round2[1]} health.")
        elif choice==2:
            print(f"{round2[0]} took {rlrd3[4]} damage!")
            round2[1]=round2[1]-rlrd3[4]
            print(f"{round2[0]} now has {round2[1]} health.")
        else:
            print('Nonvalid option')
        if round2[1]<=0:
            break
        else:
            print()
        print("Now it is the computers turn.")
        option=(1,2)
        choose=np.random.choice(option)
        if choose==1:
            print(f"Now {rlrd3[0]} has taken {round2[3]} damage.")
            rlrd3[1]=rlrd3[1]-round2[3]
            print(f"They now have {rlrd3[1]} health.")
        else:
            print(f"Now {rlrd3[0]} has taken {round2[4]} damage.")
            rlrd3[1]=rlrd3[1]-round2[4]
            print(f"They now have {rlrd3[1]} health.")
    if round2[1]<=0:
        print(f"You have defeated {round2[0]}!")
        round3=np.random.choice(aiplay)
        aiplay.remove(round3)
        if round3==4:
            round3=player4
            print(f"The computer has now chosen {round3[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        elif round3==5:
            round3=player5
            print(f"The computer has now chosen {round3[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        else:
            round3=player6
            print(f"The computer has now chosen {round3[0]} to compete.")
            print(f"Would you like to continue or conceed?")
            ans=int(input("Continue=1     Conceed=2"))
        if ans==1:
            print("Great! Lets go.")
        else:
            print("Game Over")
    else:
        print(f"Oh no! {rlrd3[0]} has been defeated!")
        print("You have lost the game. Better luck next time.")
else:
    print(f"The computer is starting with {round3[0]}.")
    while round3[1]>0 and rlrd2[1]>0:
        option=(1,2)
        choose=np.random.choice(option)
        if choose==1:
            print(f"{rlrd2[0]} has taken {round3[3]} damage!")
            rlrd2[1]=rlrd2[1]-round3[3]
            print(f"They now have {rlrd2[1]} health.")
        else:
            print(f"{rlrd2[0]} has taken {round3[4]} damage!")
            rlrd2[1]=rlrd2[1]-round3[4]
            print(f"They now have {rlrd2[1]} health.")
        if rlrd2[1]<=0:
            break
        else:
            print()
        print(f"Attack 1: {rlrd2[3]}     Attack 2: {rlrd2[4]}")
        choice=int(input(f"Which attack would you like to use on {round3[0]}?"))
        if choice==1:
            print(f"{round3[0]} took {rlrd2[3]} damage!")
            round3[1]=round3[1]-rlrd2[3]
            print(f"They now have {round1[1]} health.")
        elif choice==2:
            print(f"{round3[0]} took {rlrd2[4]} damage!")
            round3[1]=round3[1]-rlrd2[4]
            print(f"{round3[0]} now has {round3[1]} health.")
        else:
            print('Nonvalid option')
    if round3[1]<=0:
        print(f"You have defeated {round3[0]}!")
        print("Congratulations, you have won the game!")
    else:
        print(f"Oh no! {rlrd2[0]} has been defeated!")
        print(f"You have two players left, would you like to continue or conceed?")
        ans=int(input("Continue=1     Conceed=2"))
        if ans==1:
            print("Great! Lets go.")
        else:
            print("You have conceeded to the computer. The computer wins.")
        print("Here's your players: ")
        print(name1)
        print(f"hp: {hp1}, type: {tp1}, first attack: {atk1n1}, second attack: {atk2n1}")
        print(name2)
        print(f"hp: {hp2}, type: {tp2}, first attack: {atk1n2}, second attack: {atk2n2}")
        print(name3)
        print(f"hp: {hp3}, type: {tp3}, first attack: {atk1n3}, second attack: {atk2n3}")
        i=0
        while i==0:
            rlrd3=input("Which player would you like to switch to?")
            if rlrd3==name1:
                print(f"You are continuing with {name1}!")
                rlrd3=player1
                i=1
            elif rlrd3==name2:
                print(f"You are continuing with {name2}!")
                rlrd3=player2
                i=1
            elif rlrd3==name3:
                print(f"You are continuing with {name3}!")
                rlrd3=player3
                i=1
            else:
                print("That is not one of your players, try again.")
# Out:
# The computer is starting with Tom.
# Reginald has taken 11 damage!
# They now have 28 health.
#
# Attack 1: 15     Attack 2: 25
# Which attack would you like to use on Tom?2
# Tom took 25 damage!
# Tom now has 18 health.
# Reginald has taken 11 damage!
# They now have 17 health.
#
# Attack 1: 15     Attack 2: 25
# Which attack would you like to use on Tom?2
# Tom took 25 damage!
# Tom now has -7 health.
# You have defeated Tom!
# Congratulations, you have won the game!

# %%
 print(f"The computer is starting with {round3[0]}.")
    while round3[1]>0 and rlrd3[1]>0:
        option=(1,2)
        choose=np.random.choice(option)
        if choose==1:
            print(f"{rlrd3[0]} has taken {round3[3]} damage!")
            rlrd3[1]=rlrd3[1]-round3[3]
            print(f"They now have {rlrd3[1]} health.")
        else:
            print(f"{rlrd3[0]} has taken {round3[4]} damage!")
            rlrd3[1]=rlrd3[1]-round3[4]
            print(f"They now have {rlrd3[1]} health.")
        if rlrd3[1]<=0:
            break
        else:
            print()
        print(f"Attack 1: {rlrd3[3]}     Attack 2: {rlrd3[4]}")
        choice=int(input(f"Which attack would you like to use on {round3[0]}?"))
        if choice==1:
            print(f"{round3[0]} took {rlrd3[3]} damage!")
            round3[1]=round3[1]-rlrd3[3]
            print(f"They now have {round3[1]} health.")
        elif choice==2:
            print(f"{round3[0]} took {rlrd3[4]} damage!")
            round3[1]=round3[1]-rlrd3[4]
            print(f"{round3[0]} now has {round3[1]} health.")
        else:
            print('Nonvalid option')
    if round3[1]<=0:
        print(f"You have defeated {round3[0]}!")
        print("Congratulations, you have won the game!")
    else:
        print(f"Oh no! {rlrd3[0]} has been defeated!")
        print("You have lost the game. Better luck next time.")
